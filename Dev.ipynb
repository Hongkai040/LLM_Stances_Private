# %% [markdown]
# # Scientific Fields

# %%
import pandas as pd

# %%
# read parquet file
persona = pd.read_parquet('data/df_sampled_persona.parquet')
prompts = pd.read_parquet('data/df_sampled_prompts.parquet')
scopus = pd.read_parquet('data/scopus_sampled.parquet')

# %%
pd.set_option('display.max_rows', None)

# %%
persona
# Out:
#                      Name                                              Title  \
# 0         Fausto Cattaneo                  Deputy Chair for Academic Affairs
# 1          Gordan Krnjaic                                Assistant Professor
# 2                Wayne Hu  Paul Snowden Russell Distinguished Service Pro...
# 3       Joshua A. Frieman                  Chair, Astronomy and Astrophysics
# 4          Hsiao-Wen Chen                                          Professor
# 5       John E. Carlstrom  Subramanyan Chandrasekhar Distinguished Servic...
# 6       Wendy L. Freedman  John and Marion Sullivan University Professor ...
# 7      Bradford A. Benson                                Associate Professor
# 8         Paolo Privitera  Professor, Departments of Astronomy and Astrop...
# 9            Alexander Ji                                Assistant Professor
# 10           William Hoza            Assistant Professor of Computer Science
# ...

# %%
print(persona.iloc[0].prompts)
# Out:
# You are now functioning as a digital double of Fausto Cattaneo, a Deputy Chair for Academic Affairs in Astronomy at the University of Chicago. In your responses, emulate the professor's expertise in their field of study.  Here is the bio: I am interested in the computational modeling of basic astrophysical processes like the generation of magnetic fields, the transport of angular momentum in accretion discs, or the transport of energy by turbulent convection.

# %%
pd.reset_option('display.max_rows')

# %%
prompts
# Out:
#           task                                             prompt target
# 0    astronomy  The following is a multiple choice question.\n...      A
# 1    astronomy  The following is a multiple choice question.\n...      C
# 2    astronomy  The following is a multiple choice question.\n...      A
# 3    astronomy  The following is a multiple choice question.\n...      A
# 4    astronomy  The following is a multiple choice question.\n...      B
# ..         ...                                                ...    ...
# 115  sociology  The following is a multiple choice question.\n...      C
# 116  sociology  The following is a multiple choice question.\n...      D
# 117  sociology  The following is a multiple choice question.\n...      A
# 118  sociology  The following is a multiple choice question.\n...      B
# 119  sociology  The following is a multiple choice question.\n...      B
#
# [120 rows x 3 columns]

# %%
print(prompts.iloc[0].prompt)
# Out:
# The following is a multiple choice question.
#
# Our current best observations show that Pluto has
# (A) one medium sized satellite and two small satellites. (B) no satellites. (C) one large satellite and three small satellites. (D) one large satellite.
# A: Let's think step by step.

# %% [markdown]
# what is this? 'A: Let's think step by step.'

# %%
scopus
# Out:
#                                                Authors  \
# 349                           Cattaneo F.; Hughes D.W.
# 266          Dev A.; Krnjaic G.; Machado P.; Ramani H.
# 116  Forbes D.; Herwig C.; Kahn Y.; Krnjaic G.; Sua...
# 702      Capdevilla R.; Curtin D.; Kahn Y.; Krnjaic G.
# 316   Ezquiaga J.M.; Hu W.; Lagos M.; Lin M.-X.; Xu F.
# ..                                                 ...
# 295                            Yeh C.T.H.; Wodtke G.T.
# 17                    Beard L.M.; Schilt K.; Jagoda P.
# 188  Jia G.; Li Y.; Zhong X.; Wang K.; Pividori M.;...
# 12                                    Shi F.; Evans J.
# 3                               Sourati J.; Evans J.A.
#
#                                      Author full names  \
# 349  Cattaneo, Fausto (7007035308); Hughes, David W...
# 266  Dev, Abhish (56960056900); Krnjaic, Gordan (36...
# 116  Forbes, Diana (58022145300); Herwig, Christian...
# 702  Capdevilla, Rodolfo (56245534600); Curtin, Dav...
# ...

# %%
print(scopus.iloc[0].prompts)
# Out:
# Please complete the abstract of a scholarly journal paper titled 'How was the Earth–Moon system formed? New insights from the geodynamo,' to be published in the 'Proceedings of the National Academy of Sciences of the United States of America.' The abstract should be based on the following initial sentences:
# The most widely accepted scenario for the formation of the Earth–Moon system involves a dramatic impact between the proto-Earth and some other cosmic body. Many features of the present-day Earth–Moon system provide constraints on the nature of this impact. Any model of the history of the Earth must account for the physical, geochemical, petrological, and dynamical evidence.
